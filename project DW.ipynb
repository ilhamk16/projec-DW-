# %%
import pandas as pd
import sqlite3
import math
import datetime 
import numpy as np
import matplotlib.pyplot as pl

# %%
df = pd.read_csv("jumlah pegawai provinsi jawa barat.csv")
df
# Out:
#        provinsi  kode_kota_kabupaten nama_kota_kabupaten status_kepegawaian  \
# 0    JAWA BARAT                 3204        KAB. BANDUNG               PNS
# 1    JAWA BARAT                 3204        KAB. BANDUNG            YAYASAN
# 2    JAWA BARAT                 3204        KAB. BANDUNG         GURU BANTU
# 3    JAWA BARAT                 3204        KAB. BANDUNG         GURU HONDA
# 4    JAWA BARAT                 3204        KAB. BANDUNG   GURU TIDAK TETAP
# ..          ...                  ...                 ...                ...
# 130  JAWA BARAT                 3278    KOTA TASIKMALAYA               PNS
# 131  JAWA BARAT                 3278    KOTA TASIKMALAYA            YAYASAN
# 132  JAWA BARAT                 3278    KOTA TASIKMALAYA         GURU BANTU
# 133  JAWA BARAT                 3278    KOTA TASIKMALAYA         GURU HONDA
# 134  JAWA BARAT                 3278    KOTA TASIKMALAYA   GURU TIDAK TETAP
#
#      jumlah satuan
# 0       281  ORANG
# 1      1209  ORANG
# 2         0  ORANG
# 3       914  ORANG
# 4       111  ORANG
# ..      ...    ...
# 130     386  ORANG
# 131     629  ORANG
# 132       0  ORANG
# 133     190  ORANG
# 134      11  ORANG
#
# [135 rows x 6 columns]

# %%
df.sort_values(by=['jumlah'], inplace=True, ascending=False)
df
# Out:
#        provinsi  kode_kota_kabupaten nama_kota_kabupaten status_kepegawaian  \
# 16   JAWA BARAT                 3201          KAB. BOGOR            YAYASAN
# 18   JAWA BARAT                 3201          KAB. BOGOR         GURU HONDA
# 101  JAWA BARAT                 3275         KOTA BEKASI            YAYASAN
# 11   JAWA BARAT                 3216         KAB. BEKASI            YAYASAN
# 36   JAWA BARAT                 3205          KAB. GARUT            YAYASAN
# ..          ...                  ...                 ...                ...
# 82   JAWA BARAT                 3211       KAB. SUMEDANG         GURU BANTU
# 87   JAWA BARAT                 3206    KAB. TASIKMALAYA         GURU BANTU
# 92   JAWA BARAT                 3273        KOTA BANDUNG         GURU BANTU
# 97   JAWA BARAT                 3279         KOTA BANJAR         GURU BANTU
# 67   JAWA BARAT                 3214     KAB. PURWAKARTA         GURU BANTU
#
#      jumlah satuan
# 16     2711  ORANG
# 18     1923  ORANG
# 101    1580  ORANG
# 11     1554  ORANG
# 36     1450  ORANG
# ..      ...    ...
# 82        0  ORANG
# 87        0  ORANG
# 92        0  ORANG
# 97        0  ORANG
# 67        0  ORANG
#
# [135 rows x 6 columns]

# %%
x=df.head()
x
# Out:
#        provinsi  kode_kota_kabupaten nama_kota_kabupaten status_kepegawaian  \
# 16   JAWA BARAT                 3201          KAB. BOGOR            YAYASAN
# 18   JAWA BARAT                 3201          KAB. BOGOR         GURU HONDA
# 101  JAWA BARAT                 3275         KOTA BEKASI            YAYASAN
# 11   JAWA BARAT                 3216         KAB. BEKASI            YAYASAN
# 36   JAWA BARAT                 3205          KAB. GARUT            YAYASAN
#
#      jumlah satuan
# 16     2711  ORANG
# 18     1923  ORANG
# 101    1580  ORANG
# 11     1554  ORANG
# 36     1450  ORANG

# %%
x.plot()
